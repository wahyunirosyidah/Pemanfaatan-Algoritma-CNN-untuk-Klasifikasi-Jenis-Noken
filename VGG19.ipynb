# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyunirosyidah/Pemanfaatan-Algoritma-CNN-untuk-Klasifikasi-Jenis-Noken/blob/main/VGG19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from io import BytesIO
from ipywidgets import widgets
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import time

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/SKRIPSI AYU'
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1-jj4VBbytrWOWERorcKBNzdHNrPO6mXj/SKRIPSI AYU

# %%
# Directory Path
BASE_DIR = 'Dataset Binary'
print(f"Base Directory: {os.listdir(BASE_DIR)}")

data_train=f'{BASE_DIR}/train'
print(f"Train Directory: {sorted(os.listdir(data_train))}")
data_validation=f'{BASE_DIR}/valid'
print(f"Valid Directory: {sorted(os.listdir(data_validation))}")
# Out:
# Base Directory: ['train', 'valid']
# Train Directory: ['Bitu Agia', 'Junum Ese']
# Valid Directory: ['Bitu Agia', 'Junum Ese']

# %%
# Plot noken Images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle('Noken Images', fontsize=16)

# List of noken
noken_list = os.listdir(data_train)
# Plot images for each noken
for i, noken in enumerate(noken_list):
    dir_path = f'{data_train}/{noken}'
    img = tf.keras.preprocessing.image.load_img(dir_path + '/' + os.listdir(dir_path)[0])
    # row, col = divmod(i, 3)
    axes[i].imshow(img)
    axes[i].set_title(f'Example of Noken: {noken}')
    axes[i].axis('off')

# Disable axis on empty subplots if any
for jj in range(len(noken_list), 9):
    row, col = divmod(jj, 3)
    axes[i].axis('off')

plt.show()

# %%
BATCH_SIZE=32
IMAGE_SIZE=224
LABEL_MODE='binary'

# Prepare the training set
train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_train,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE
    )

# Prepare the validation set
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    data_validation,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE
    )
# Out:
# Found 400 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.

# %%
FILL_MODE='reflect'

data_augmentation=tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2, 0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomShear(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)

])

data_rescaling = tf.keras.layers.Rescaling(1./255)

# %%
def preprocess_train(images, labels):
    images = data_augmentation(images, training=True)
    images = data_rescaling(images)
    return images, labels

def preprocess_val(images, labels):
    images = data_rescaling(images)
    return images, labels

train_dataset = train_dataset.map(preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.map(preprocess_val, num_parallel_calls=tf.data.AUTOTUNE)

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# Ambil satu batch dan dua gambar pertama
images, labels = next(iter(train_dataset))
samples = images[:2]

# Buat grid 2 baris × 4 kolom dengan figsize lebih lebar
fig, axes = plt.subplots(2, 4, figsize=(16, 8), squeeze=False)
fig.suptitle("Hasil Augmentasi", fontsize=18)

for row, img in enumerate(samples):
    for col in range(4):
        aug = data_augmentation(tf.expand_dims(img, 0), training=True)[0]
        axes[row, col].imshow(aug.numpy())
        axes[row, col].axis('off')
        axes[row, col].set_title(f'Gambar {row+1}-Augmentasi{col+1}', fontsize=12)

# Atur jarak antar subplot
plt.subplots_adjust(wspace=0.05, hspace=0.1, top=0.90)

plt.show()

# %%
#Optimasi
SHUFFLE_BUFFER_SIZE=500
PREFETCH_BUFFER_SIZE=tf.data.AUTOTUNE

train_dataset_final=(
    train_dataset
    .cache()
    .shuffle(SHUFFLE_BUFFER_SIZE)
    .prefetch(PREFETCH_BUFFER_SIZE)
)

validation_dataset_final=(
    validation_dataset
    .cache()
    .prefetch(PREFETCH_BUFFER_SIZE)
)

# %%
base_model = tf.keras.applications.VGG19(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
                                               include_top=False,
                                               weights='imagenet'
                                               )
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# # Membangun Model
def create_model(base_model):
    inputs = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_output = base_model(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(base_output)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    # Output Layer
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    # Buat Model
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
model = create_model(base_model)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,090,689 (76.64 MB)
#  Trainable params: 66,049 (258.00 KB)
#  Non-trainable params: 20,024,640 (76.39 MB)

# %%
# Constant for epochs
EPOCHS = 50

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
    )

# Mulai menghitung waktu
start_time_no_optim = time.time()

# Train the model
history = model.fit(
    train_dataset_final,
    epochs=EPOCHS,
    validation_data=validation_dataset_final,
    verbose=1
)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.5629 - loss: 0.7811 - val_accuracy: 0.5000 - val_loss: 0.6933
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.6186 - loss: 0.7316 - val_accuracy: 0.5400 - val_loss: 0.6817
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.7158 - loss: 0.5970 - val_accuracy: 0.6200 - val_loss: 0.6712
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 256ms/step - accuracy: 0.7116 - loss: 0.5573 - val_accuracy: 0.6600 - val_loss: 0.6611
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - accuracy: 0.7399 - loss: 0.5115 - val_accuracy: 0.7000 - val_loss: 0.6509
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.7896 - loss: 0.4455 - val_accuracy: 0.6800 - val_loss: 0.6412
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - accuracy: 0.7592 - loss: 0.4450 - val_accuracy: 0.7000 - val_loss: 0.6305
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.8079 - loss: 0.4460 - val_accuracy: 0.7600 - val_loss: 0.6199
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.7944 - loss: 0.4210 - val_accuracy: 0.7400 - val_loss: 0.6089
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.8160 - loss: 0.3883 - val_accuracy: 0.7600 - val_loss: 0.5978
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.8506 - loss: 0.3540 - val_accuracy: 0.7600 - val_loss: 0.5864
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.8712 - loss: 0.3452 - val_accuracy: 0.7600 - val_loss: 0.5754
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - accuracy: 0.8575 - loss: 0.3104 - val_accuracy: 0.7700 - val_loss: 0.5641
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.8522 - loss: 0.3405 - val_accuracy: 0.8000 - val_loss: 0.5514
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - accuracy: 0.8847 - loss: 0.2861 - val_accuracy: 0.8000 - val_loss: 0.5387
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - accuracy: 0.8561 - loss: 0.3310 - val_accuracy: 0.8000 - val_loss: 0.5262
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.8918 - loss: 0.2677 - val_accuracy: 0.8000 - val_loss: 0.5156
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.9054 - loss: 0.2402 - val_accuracy: 0.7900 - val_loss: 0.5063
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - accuracy: 0.8819 - loss: 0.2805 - val_accuracy: 0.8000 - val_loss: 0.4927
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - accuracy: 0.9042 - loss: 0.2556 - val_accuracy: 0.8100 - val_loss: 0.4809
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - accuracy: 0.8520 - loss: 0.3231 - val_accuracy: 0.8100 - val_loss: 0.4694
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.9070 - loss: 0.2389 - val_accuracy: 0.8200 - val_loss: 0.4608
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - accuracy: 0.9041 - loss: 0.2400 - val_accuracy: 0.8300 - val_loss: 0.4471
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9090 - loss: 0.2062 - val_accuracy: 0.8300 - val_loss: 0.4392
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - accuracy: 0.9407 - loss: 0.1970 - val_accuracy: 0.8200 - val_loss: 0.4344
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - accuracy: 0.8897 - loss: 0.2467 - val_accuracy: 0.8400 - val_loss: 0.4317
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 0.8955 - loss: 0.2579 - val_accuracy: 0.8400 - val_loss: 0.4271
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - accuracy: 0.9184 - loss: 0.2025 - val_accuracy: 0.8500 - val_loss: 0.4177
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - accuracy: 0.8848 - loss: 0.2427 - val_accuracy: 0.8500 - val_loss: 0.4159
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - accuracy: 0.9202 - loss: 0.2020 - val_accuracy: 0.8600 - val_loss: 0.4051
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - accuracy: 0.9542 - loss: 0.1750 - val_accuracy: 0.8700 - val_loss: 0.3994
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9078 - loss: 0.2512 - val_accuracy: 0.9000 - val_loss: 0.3859
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9118 - loss: 0.2179 - val_accuracy: 0.9000 - val_loss: 0.3774
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - accuracy: 0.9463 - loss: 0.1705 - val_accuracy: 0.9000 - val_loss: 0.3705
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9463 - loss: 0.1727 - val_accuracy: 0.9000 - val_loss: 0.3650
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9305 - loss: 0.1816 - val_accuracy: 0.9000 - val_loss: 0.3554
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.9468 - loss: 0.1546 - val_accuracy: 0.9000 - val_loss: 0.3501
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - accuracy: 0.9403 - loss: 0.1803 - val_accuracy: 0.9000 - val_loss: 0.3516
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.9159 - loss: 0.1832 - val_accuracy: 0.9000 - val_loss: 0.3534
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - accuracy: 0.9593 - loss: 0.1397 - val_accuracy: 0.9000 - val_loss: 0.3441
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - accuracy: 0.9509 - loss: 0.1493 - val_accuracy: 0.9000 - val_loss: 0.3461
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - accuracy: 0.9480 - loss: 0.1597 - val_accuracy: 0.9000 - val_loss: 0.3516
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - accuracy: 0.9559 - loss: 0.1558 - val_accuracy: 0.9000 - val_loss: 0.3563
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.9284 - loss: 0.1607 - val_accuracy: 0.9000 - val_loss: 0.3454
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.9547 - loss: 0.1515 - val_accuracy: 0.9000 - val_loss: 0.3473
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.9436 - loss: 0.1565 - val_accuracy: 0.9100 - val_loss: 0.3415
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 0.9572 - loss: 0.1550 - val_accuracy: 0.9100 - val_loss: 0.3323
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - accuracy: 0.9693 - loss: 0.1310 - val_accuracy: 0.9100 - val_loss: 0.3264
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - accuracy: 0.9825 - loss: 0.1044 - val_accuracy: 0.9100 - val_loss: 0.3324
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.9672 - loss: 0.1327 - val_accuracy: 0.9100 - val_loss: 0.3324

# %%
#Berhenti menghitung waktu
end_time_no_optim = time.time()

# %%
# Get training and validation accuracies
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle('Training and validation accuracy VGG19')

for i, (data, label) in enumerate(zip([(acc, val_acc), (loss, val_loss)], ["Accuracy", "Loss"])):
    ax[i].plot(epochs, data[0], 'steelblue', label="Training " + label)
    ax[i].plot(epochs, data[1], 'darkorange', label="Validation " + label)
    ax[i].legend()
    ax[i].set_xlabel('epochs')

plt.show()

# %%
# Get training and validation accuracies
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

fig, ax = plt.subplots(1, 2, figsize=(8, 7))
fig.suptitle('Training and validation accuracy VGG19')

for i, (data, label) in enumerate(zip([(acc, val_acc), (loss, val_loss)], ["Accuracy", "Loss"])):
    ax[i].plot(epochs, data[0], 'steelblue', label="Training " + label)
    ax[i].plot(epochs, data[1], 'darkorange', label="Validation " + label)
    ax[i].legend()
    ax[i].set_xlabel('epochs')

plt.show()

# %%
# Hitung jumlah file di dataset validasi
num_test_files = sum([len(files) for _, _, files in os.walk(data_validation)])
num_test_files = sum([len(files) for _, _, files in os.walk(data_train)])
num_test_steps = num_test_files // BATCH_SIZE  # Total batch yang akan dievaluasi

# Evaluasi model
loss, acc = model.evaluate(train_dataset_final, steps=num_test_steps, verbose=1)
val_loss, val_acc = model.evaluate(validation_dataset_final, steps=num_test_steps, verbose=1)

print(f"Train Loss: {loss * 100:.2f} %")
print(f"Train Accuracy: {acc * 100:.2f} %")
print(f"Validation Loss: {val_loss * 100:.2f} %")
print(f"Validation Accuracy: {val_acc * 100:.2f} %")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9690 - loss: 0.1033
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8999 - loss: 0.3574
# Train Loss: 12.67 %
# Train Accuracy: 96.20 %
# Validation Loss: 33.24 %
# Validation Accuracy: 91.00 %
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
duration = end_time_no_optim - start_time_no_optim
print(f"Waktu pelatihan tanpa optimasi: {duration:.2f} detik")
# Out:
# Waktu pelatihan tanpa optimasi: 319.34 detik

# %%
minutes, seconds = divmod(duration, 60)
print(f"Waktu pelatihan: {int(minutes)} menit {seconds:.2f} detik")
# Out:
# Waktu pelatihan: 5 menit 19.34 detik

# %%
# Menghitung durasi dalam detik
duration_in_seconds = end_time_no_optim - start_time_no_optim

# Mengubah durasi ke dalam format menit dan detik
minutes = int(duration_in_seconds // 60)
seconds = int(duration_in_seconds % 60)

# Menampilkan durasi pelatihan
print(f"Waktu pelatihan tanpa optimasi: {minutes} menit {seconds} detik")
# Out:
# Waktu pelatihan tanpa optimasi: 5 menit 19 detik

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Simpan class names
raw_train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_train,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    seed=42
)
class_names = raw_train_dataset.class_names

# Evaluasi Model
y_true = []
y_pred = []

for images, labels in validation_dataset_final:
    preds = model.predict(images)
    y_true.extend(labels.numpy().astype(int))  # true labels
    y_pred.extend((preds > 0.5).astype(int).flatten())  # binary predictions

# Convert to array
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Hitung error per class (0 dan 1)
errors_per_class = conf_matrix.sum(axis=1) - np.diag(conf_matrix)

# Label kelas 0 dan 1
filtered_labels = [label for label, errors in zip(class_names, errors_per_class) if errors > 0]
filtered_errors = [errors for errors in errors_per_class if errors > 0]

# Visualisasi Errors by Class
if len(filtered_labels) > 0:
    colors = plt.cm.tab10(np.linspace(0, 1, len(filtered_labels)))
    plt.figure(figsize=(8, len(filtered_labels) * 0.6))
    plt.barh(filtered_labels, filtered_errors, color=colors)
    plt.title('Errors by Class on Validation Set', fontsize=12)
    plt.xlabel('Number of Errors', fontsize=10)
    plt.ylabel('Class Labels', fontsize=10)
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("Tidak ada kelas yang memiliki error!")

# Confusion Matrix Plot
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix VGG19')
plt.show()

# Classification Report
print("Classification Report VGG19:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 400 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# Classification Report VGG19:
#               precision    recall  f1-score   support
#
#    Bitu Agia       0.86      0.98      0.92        50
#    Junum Ese       0.98      0.84      0.90        50
#
#     accuracy                           0.91       100
#    macro avg       0.92      0.91      0.91       100
# weighted avg       0.92      0.91      0.91       100

# %%
# Reload class names from training data
raw_train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_train,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    seed=42
)
class_names = raw_train_dataset.class_names

# Model Evaluation
y_true = []
y_pred = []

# Loop to predict on the validation set
for images, labels in validation_dataset_final:
    preds = model.predict(images)
    y_true.extend(labels.numpy().astype(int))  # Save the true labels
    y_pred.extend((preds > 0.5).astype(int).flatten())  # Save binary predictions

# Convert lists to arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Visualization of Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix VGG19')
plt.show()

# Classification Report
print("Classification Report VGG19:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 400 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Classification Report VGG19:
#               precision    recall  f1-score   support
#
#    Bitu Agia       0.86      0.98      0.92        50
#    Junum Ese       0.98      0.84      0.90        50
#
#     accuracy                           0.91       100
#    macro avg       0.92      0.91      0.91       100
# weighted avg       0.92      0.91      0.91       100
